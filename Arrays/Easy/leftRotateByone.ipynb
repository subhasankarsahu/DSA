# %%
def leftRotate(arr):
    if not arr:
        return arr
    
    temp = arr[0]
    for i in range(1, len(arr)):
        arr[i - 1] = arr[i]
        
    arr[-1] = temp
    return arr

arr = [1, 2, 3, 4, 5]
print(leftRotate(arr))
# Out:
# [2, 3, 4, 5, 1]

# %%
def leftRotate(arr):
    return arr[1:] + arr[:1]

arr = [1, 2, 3, 4, 5]
print(leftRotate(arr))
# Out:
# [2, 3, 4, 5, 1]
